# %%
from vahun.tools import logread
# %matplotlib inline

# %%
log=logread()
log.plot_accuracy()
# Out:
# ['acc_evolve20170311214046', ['Language', 'Hun'], ['Wordcount', '75191'], ['Unique words', '25545'], ['Population size', '40'], ['Encoding dim', '80'], ['Encoder type', 'Accuracy_tracker_80'], ['nonlinear', '<function relu at 0x7fc19fde51e0>'], ['population_size', '40']]
# Max test accuracy: 0.8198949398231266
# Max train accuracy: 0.8166644500598483
# With config:  [80, 249, 278, 360]
# ['acc_evolve_10_20170312165053', ['Language', 'Hun'], ['Wordcount', '748072'], ['Unique words', '135416'], ['Population size', '40'], ['Encoding dim', '10'], ['Encoder type', 'Accuracy_tracker_10'], ['nonlinear', '<function sigmoid at 0x7f96c10408c8>'], ['population_size', '40']]
# Max test accuracy: 0.7780857534338135
# Max train accuracy: 0.7842237621082216
# With config:  [348, 254, 10, 254, 348, 360]
# ...

# %%
open(self.corpus_path,encoding='utf8')
