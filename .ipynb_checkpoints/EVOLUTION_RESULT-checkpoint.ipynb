# %%
from tools import logread
# %matplotlib inline

# %%
log=logread()
log.plot_accuracy()
# Out:
# ['acc_evolve20170311214046', ['Language', 'Hun'], ['Wordcount', '75191'], ['Unique words', '25545'], ['Population size', '40'], ['Encoding dim', '80'], ['Encoder type', 'Accuracy_tracker_80'], ['nonlinear', '<function relu at 0x7fc19fde51e0>'], ['population_size', '40']]
# Max test accuracy: 0.8198949398231266
# Max train accuracy: 0.8166644500598483
# With config:  [80, 249, 278, 360]
# ['acc_evolve_330_20170312143750', ['Language', 'Hun'], ['Wordcount', '75191'], ['Unique words', '25545'], ['Population size', '40'], ['Encoding dim', '330'], ['Encoder type', 'Accuracy_tracker_330'], ['nonlinear', '<function relu at 0x7f6e2e664268>'], ['population_size', '40']]
# Max test accuracy: 0.8638007846266375
# Max train accuracy: 0.8564852373985903
# With config:  [330, 360]
# ...
