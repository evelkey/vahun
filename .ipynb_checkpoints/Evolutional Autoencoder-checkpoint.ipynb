# %%
import tensorflow as tf

from corpus import Corpus
import numpy as np

from tools import Timer
from tools import explog
from autoencoders import Autoencoder_ffnn
from genetic import evolution
from genetic import experiment

config = tf.ConfigProto()
config.gpu_options.allow_growth = True
config.gpu_options.per_process_gpu_memory_fraction=0.5

# %%
corp_path='/home/velkey/corp/webkorpusz.wpl'
corp=Corpus(corpus_path=corp_path,language="Hun",size=100000,encoding_len=10)
all_features=corp.featurize_data_charlevel_onehot(corp.hun_lower)
train=all_features[0:int(len(all_features)*0.8)]
test=all_features[int(len(all_features)*0.8):len(all_features)]
x_train = train.reshape((len(train), np.prod(train.shape[1:])))
x_test = test.reshape((len(test), np.prod(test.shape[1:])))
print(x_train.shape)
# Out:
# Corpus initalized, fields: ['unique', 'lower', 'hun_lower', 'lower_unique', 'hun_lower_unique']
# Unique words:  25545
# (60152, 360)

# %%
logger=explog(encoder_type="Autoencoder",
              encoding_dim=80,feature_len=10,
              lang="Hun",unique_words=len(set(corp.full)),
              name="Autoencoder_evolution",population_size=80,
              words=len(corp.hun_lower))

# %%
x23=evolution(x_train,x_test,80,100,360,config,logger)
for i in range(30):
    for i in range(x23.population_size):
        print(x23.population[i].experiment.weights)
        
    x23.evolve()
    print(x23.grade())
# Out:
# Initializing new population
# new gen took:  93.16964530944824  s
# [177, 134, 174, 100, 122, 78, 113, 360]
# [182, 148, 100, 115, 68, 360]
# [114, 149, 145, 100, 99, 96, 174, 360]
# [100, 360]
# [12, 22, 189, 140, 100, 198, 44, 27, 162, 360]
# [150, 87, 116, 100, 163, 88, 160, 360]
# [172, 141, 12, 100, 197, 114, 185, 360]
# [105, 191, 27, 48, 100, 31, 125, 159, 157, 360]
# [197, 72, 43, 77, 100, 45, 79, 170, 121, 360]
# [166, 61, 100, 127, 105, 360]
# [30, 26, 133, 55, 100, 56, 64, 200, 35, 360]
# [109, 22, 112, 13, 100, 184, 144, 60, 96, 360]
# [135, 168, 175, 100, 187, 15, 76, 360]
# [200, 145, 52, 81, 100, 189, 15, 136, 109, 360]
# [100, 360]
# [100, 360]
# [172, 118, 100, 184, 118, 360]
# [156, 126, 100, 15, 153, 360]
# [197, 138, 100, 153, 92, 360]
# [65, 49, 12, 156, 100, 119, 116, 188, 184, 360]
# [122, 52, 34, 61, 100, 87, 24, 85, 174, 360]
# [104, 115, 187, 188, 100, 146, 75, 60, 100, 360]
# [66, 12, 57, 100, 125, 195, 135, 360]
# [100, 360]
# [132, 68, 44, 43, 100, 91, 172, 108, 182, 360]
# [191, 41, 100, 84, 193, 360]
# [100, 360]
# [48, 138, 52, 34, 100, 180, 133, 90, 48, 360]
# [180, 91, 184, 135, 100, 52, 32, 48, 173, 360]
# [94, 176, 100, 88, 149, 360]
# [172, 100, 96, 360]
# [76, 73, 100, 155, 90, 360]
# [176, 135, 100, 120, 54, 360]
# [181, 100, 17, 360]
# [18, 100, 168, 360]
# [40, 196, 100, 12, 112, 360]
# [70, 100, 140, 360]
# [40, 100, 193, 360]
# [100, 360]
# [166, 171, 178, 193, 100, 134, 73, 109, 43, 360]
# [171, 191, 100, 162, 155, 360]
# [100, 360]
# [100, 360]
# [104, 100, 149, 360]
# [110, 21, 100, 64, 12, 360]
# [151, 134, 100, 97, 172, 360]
# [18, 100, 170, 360]
# [91, 100, 31, 360]
# [107, 64, 92, 100, 27, 112, 165, 360]
# [50, 91, 99, 100, 60, 45, 174, 360]
# [197, 42, 168, 100, 157, 69, 175, 360]
# [120, 11, 100, 104, 39, 360]
# [75, 100, 24, 360]
# [49, 132, 100, 100, 99, 190, 108, 360]
# [151, 100, 107, 360]
# [119, 57, 100, 106, 115, 360]
# [115, 11, 100, 44, 139, 360]
# [170, 152, 168, 35, 100, 51, 77, 148, 68, 360]
# [108, 187, 164, 100, 14, 74, 146, 360]
# [32, 100, 132, 360]
# [149, 143, 198, 100, 187, 44, 157, 360]
# [46, 36, 132, 87, 100, 23, 190, 63, 86, 360]
# [159, 156, 163, 149, 100, 143, 184, 186, 182, 360]
# [168, 195, 25, 100, 101, 36, 94, 360]
# [182, 192, 100, 56, 82, 360]
# [47, 104, 100, 182, 146, 360]
# [100, 360]
# [172, 92, 67, 100, 82, 25, 46, 360]
# [159, 47, 87, 100, 24, 191, 143, 360]
# [100, 360]
# [159, 100, 141, 360]
# [50, 115, 195, 108, 100, 139, 31, 50, 46, 360]
# [129, 100, 152, 360]
# [182, 107, 74, 97, 100, 156, 160, 174, 158, 360]
# [60, 100, 106, 360]
# [34, 100, 164, 360]
# [75, 108, 100, 46, 35, 360]
# [168, 161, 101, 37, 100, 72, 126, 92, 99, 360]
# [40, 100, 135, 360]
# [20, 100, 42, 360]
# STOPPED OVERFIT
# Epoch: 0001 cost= 3269.087693214
# STOPPED OVERFIT
# Epoch: 0001 cost= 61.416514635
# STOPPED OVERFIT
# Epoch: 0001 cost= 1891.247353315
# STOPPED OVERFIT
# Epoch: 0001 cost= 61.751801252
# STOPPED OVERFIT
# Epoch: 0001 cost= 1242.181317091
# STOPPED OVERFIT
# Epoch: 0001 cost= 63.281904936
# Epoch: 0001 cost= 1756.634678125
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 33.207166076
# STOPPED OVERFIT
# Epoch: 0001 cost= 1322.830647945
# STOPPED OVERFIT
# Epoch: 0001 cost= 63.492128849
# STOPPED OVERFIT
# Epoch: 0001 cost= 989.362519026
# Epoch: 0001 cost= 328.342515469
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 1163.845484018
# STOPPED OVERFIT
# Epoch: 0001 cost= 285.778468132
# STOPPED OVERFIT
# Epoch: 0001 cost= 1147.920037746
# STOPPED OVERFIT
# Epoch: 0001 cost= 63.431295395
# STOPPED OVERFIT
# Epoch: 0001 cost= 1138.072647333
# STOPPED OVERFIT
# Epoch: 0001 cost= 63.128917217
# Epoch: 0001 cost= 1214.771224737
# STOPPED OVERFIT
# Epoch: 0001 cost= 313.072835445
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 1204.187711000
# STOPPED OVERFIT
# Epoch: 0001 cost= 63.464246035
# STOPPED OVERFIT
# Epoch: 0001 cost= 998.445706606
# STOPPED OVERFIT
# Epoch: 0001 cost= 63.945514917
# STOPPED OVERFIT
# Epoch: 0001 cost= 1157.926090479
# STOPPED OVERFIT
# Epoch: 0001 cost= 63.522269487
# STOPPED OVERFIT
# Epoch: 0001 cost= 1026.647917509
# STOPPED OVERFIT
# Epoch: 0001 cost= 62.135639668
# Epoch: 0001 cost= 1615.095547915
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 60.328419328
# Epoch: 0001 cost= 1455.908154726
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 37.714284301
# Epoch: 0001 cost= 1175.908064842
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 48.182967901
# Epoch: 0001 cost= 980.801650047
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 51.112329483
# Epoch: 0001 cost= 1217.896219969
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 48.698565006
# STOPPED OVERFIT
# Epoch: 0001 cost= 844.853521824
# STOPPED OVERFIT
# Epoch: 0001 cost= 67.087155581
# STOPPED OVERFIT
# Epoch: 0001 cost= 1021.725184917
# STOPPED OVERFIT
# Epoch: 0001 cost= 63.986646652
# STOPPED OVERFIT
# Epoch: 0001 cost= 1123.963413000
# STOPPED OVERFIT
# Epoch: 0001 cost= 63.370215178
# STOPPED OVERFIT
# Epoch: 0001 cost= 1030.244812489
# STOPPED OVERFIT
# Epoch: 0001 cost= 72.406487703
# Epoch: 0001 cost= 1529.409422398
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 40.149618506
# STOPPED OVERFIT
# Epoch: 0001 cost= 956.411849260
# STOPPED OVERFIT
# Epoch: 0001 cost= 63.332595587
# Epoch: 0001 cost= 988.051034927
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 49.684718370
# Epoch: 0001 cost= 1377.893253565
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 73.401396871
# STOPPED OVERFIT
# Epoch: 0001 cost= 1223.862799406
# STOPPED OVERFIT
# Epoch: 0001 cost= 62.901662111
# STOPPED OVERFIT
# Epoch: 0001 cost= 1019.252227306
# Epoch: 0001 cost= 313.541687489
# STOPPED OVERFIT
# Epoch: 0001 cost= 1077.365011215
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 217.505608320
# Epoch: 0001 cost= 1163.680154085
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 46.966760874
# STOPPED OVERFIT
# Epoch: 0001 cost= 1126.551266909
# Epoch: 0001 cost= 325.573756218
# STOPPED OVERFIT
# Epoch: 0001 cost= 1349.839087725
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 48.865367174
# STOPPED OVERFIT
# Epoch: 0001 cost= 1442.503060341
# STOPPED OVERFIT
# Epoch: 0001 cost= 61.189794540
# Epoch: 0001 cost= 1025.650014877
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 48.336131096
# STOPPED OVERFIT
# Epoch: 0001 cost= 1254.244200706
# STOPPED OVERFIT
# Epoch: 0001 cost= 290.386058331
# Epoch: 0001 cost= 1099.275981665
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 44.635289669
# Epoch: 0001 cost= 1044.486196280
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 50.344389439
# Epoch: 0001 cost= 1485.955801845
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 37.911298871
# STOPPED OVERFIT
# Epoch: 0001 cost= 1297.368336439
# STOPPED OVERFIT
# Epoch: 0001 cost= 64.248115540
# STOPPED OVERFIT
# Epoch: 0001 cost= 1035.210134983
# STOPPED OVERFIT
# Epoch: 0001 cost= 62.395171881
# Epoch: 0001 cost= 1362.609518051
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 33.876981258
# Epoch: 0001 cost= 1253.565210938
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 34.245498061
# Epoch: 0001 cost= 975.068392038
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 45.265150666
# STOPPED OVERFIT
# Epoch: 0001 cost= 1722.991107225
# STOPPED OVERFIT
# Epoch: 0001 cost= 63.572432518
# Epoch: 0001 cost= 1095.613171339
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 47.487658024
# STOPPED OVERFIT
# Epoch: 0001 cost= 1025.645547390
# STOPPED OVERFIT
# Epoch: 0001 cost= 61.958149433
# STOPPED OVERFIT
# Epoch: 0001 cost= 1912.137296677
# STOPPED OVERFIT
# Epoch: 0001 cost= 62.097121239
# STOPPED OVERFIT
# Epoch: 0001 cost= 937.543215275
# STOPPED OVERFIT
# Epoch: 0001 cost= 63.349010468
# STOPPED OVERFIT
# Epoch: 0001 cost= 1023.161788940
# STOPPED OVERFIT
# Epoch: 0001 cost= 62.600505590
# STOPPED OVERFIT
# Epoch: 0001 cost= 919.857460737
# STOPPED OVERFIT
# Epoch: 0001 cost= 62.732346296
# Epoch: 0001 cost= 1759.500025511
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 48.703450203
# STOPPED OVERFIT
# Epoch: 0001 cost= 1566.784542799
# STOPPED OVERFIT
# Epoch: 0001 cost= 63.019401073
# STOPPED OVERFIT
# Epoch: 0001 cost= 1093.550442934
# STOPPED OVERFIT
# Epoch: 0001 cost= 62.716718435
# Epoch: 0001 cost= 1157.572577477
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 108.129791260
# STOPPED OVERFIT
# Epoch: 0001 cost= 1116.260102034
# Epoch: 0001 cost= 323.443258762
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 1098.070346117
# STOPPED OVERFIT
# Epoch: 0001 cost= 63.162494421
# Epoch: 0001 cost= 1257.674911976
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 51.288709164
# STOPPED OVERFIT
# Epoch: 0001 cost= 892.518082619
# STOPPED OVERFIT
# Epoch: 0001 cost= 63.948850393
# Epoch: 0001 cost= 1257.201085806
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 47.643182993
# STOPPED OVERFIT
# Epoch: 0001 cost= 1011.403704643
# STOPPED OVERFIT
# Epoch: 0001 cost= 62.791662693
# STOPPED OVERFIT
# Epoch: 0001 cost= 1305.134407759
# STOPPED OVERFIT
# Epoch: 0001 cost= 63.655053139
# STOPPED OVERFIT
# Epoch: 0001 cost= 1032.809839010
# STOPPED OVERFIT
# Epoch: 0001 cost= 63.331335783
# STOPPED OVERFIT
# Epoch: 0001 cost= 1238.706415415
# STOPPED OVERFIT
# Epoch: 0001 cost= 181.336070061
# Epoch: 0001 cost= 1243.382692575
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 48.596864939
# Epoch: 0001 cost= 1000.190963030
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 49.956644297
# Epoch: 0001 cost= 1381.688789368
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 61.513970494
# STOPPED OVERFIT
# Epoch: 0001 cost= 1423.598523855
# STOPPED OVERFIT
# Epoch: 0001 cost= 63.116505146
# STOPPED OVERFIT
# Epoch: 0001 cost= 1057.197032928
# STOPPED OVERFIT
# Epoch: 0001 cost= 63.807871103
# Epoch: 0001 cost= 1422.698976040
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 34.186063528
# Epoch: 0001 cost= 1320.697098017
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 45.833073616
# STOPPED OVERFIT
# Epoch: 0001 cost= 1140.486558437
# STOPPED OVERFIT
# Epoch: 0001 cost= 62.911396980
# Epoch: 0001 cost= 1160.331512451
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 47.690248251
# STOPPED OVERFIT
# Epoch: 0001 cost= 1001.118479729
# Epoch: 0001 cost= 330.920344591
# STOPPED OVERFIT
# Epoch: 0001 cost= 1208.204449892
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 55.854389191
# Epoch: 0001 cost= 1241.235053539
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 48.733558655
# STOPPED OVERFIT
# Epoch: 0001 cost= 1437.602675438
# STOPPED OVERFIT
# Epoch: 0001 cost= 62.851939201
# STOPPED OVERFIT
# Epoch: 0001 cost= 1202.720243216
# STOPPED OVERFIT
# Epoch: 0001 cost= 63.208472013
# Epoch: 0001 cost= 1159.319532394
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 49.538954735
# STOPPED OVERFIT
# Epoch: 0001 cost= 1397.407517672
# STOPPED OVERFIT
# Epoch: 0001 cost= 63.193086386
# New generation is being created.
# new gen took:  218.7977912425995  s
# 39210.0025391
# [100, 360]
# [100, 360]
# [100, 360]
# [100, 360]
# [100, 360]
# [100, 360]
# [100, 360]
# [100, 360]
# [100, 360]
# [100, 360]
# [159, 100, 141, 360]
# [151, 100, 107, 360]
# [100, 360]
# [104, 100, 149, 360]
# [94, 176, 100, 88, 149, 360]
# [151, 134, 100, 97, 172, 360]
# [191, 41, 100, 84, 193, 360]
# [114, 149, 145, 100, 99, 96, 174, 360]
# [12, 22, 189, 140, 100, 198, 44, 27, 162, 360]
# [104, 100, 360]
# [114, 149, 145, 100, 149, 360]
# [159, 100, 107, 360]
# [100, 360]
# [100, 360]
# [114, 149, 145, 100, 84, 193, 360]
# [100, 97, 172, 360]
# [104, 100, 360]
# [100, 107, 360]
# [12, 22, 189, 140, 100, 360]
# [100, 99, 96, 174, 360]
# [12, 22, 189, 140, 100, 360]
# [104, 100, 360]
# [100, 99, 96, 174, 360]
# [100, 360]
# [104, 100, 360]
# [151, 134, 100, 360]
# [100, 360]
# [151, 100, 141, 360]
# [100, 360]
# [100, 198, 44, 27, 162, 360]
# [100, 360]
# [12, 22, 189, 140, 100, 360]
# [100, 360]
# [159, 100, 360]
# [100, 88, 149, 360]
# [100, 107, 360]
# [114, 149, 145, 100, 360]
# [100, 88, 149, 360]
# [12, 22, 189, 140, 100, 360]
# [151, 100, 97, 172, 360]
# [151, 100, 97, 172, 360]
# [104, 100, 360]
# [100, 360]
# [151, 100, 360]
# [94, 176, 100, 360]
# [100, 84, 193, 360]
# [100, 198, 44, 27, 162, 360]
# [12, 22, 189, 140, 100, 360]
# [100, 149, 360]
# [100, 141, 360]
# [100, 360]
# [100, 360]
# [191, 41, 100, 88, 149, 360]
# [100, 141, 360]
# [100, 360]
# [94, 176, 100, 107, 360]
# [191, 41, 100, 360]
# [12, 22, 189, 140, 100, 141, 360]
# [100, 84, 193, 360]
# [191, 41, 100, 360]
# [151, 134, 100, 149, 360]
# [100, 84, 193, 360]
# [100, 360]
# [100, 360]
# [94, 176, 100, 360]
# [100, 99, 96, 174, 360]
# [104, 100, 360]
# [100, 360]
# [191, 41, 100, 99, 96, 174, 360]
# [100, 360]
# Epoch: 0001 cost= 3438.940227985
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 33.463891029
# Epoch: 0001 cost= 1566.892781973
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 33.154745817
# Epoch: 0001 cost= 1419.872060537
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 69.112474203
# Epoch: 0001 cost= 1486.772848845
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 34.024329185
# Epoch: 0001 cost= 1532.406603336
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 40.564732432
# Epoch: 0001 cost= 1328.771304131
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 77.291399717
# Epoch: 0001 cost= 1306.976852417
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 80.706320047
# Epoch: 0001 cost= 1455.048872948
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 40.962650299
# Epoch: 0001 cost= 1418.952204227
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 35.842277169
# Epoch: 0001 cost= 1449.523321152
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 32.744738102
# Epoch: 0001 cost= 1047.029054642
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 42.666594028
# Epoch: 0001 cost= 1116.622638226
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 56.808793426
# Epoch: 0001 cost= 1537.891692638
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 37.923291564
# Epoch: 0001 cost= 1229.630976677
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 43.223965764
# Epoch: 0001 cost= 1055.652617931
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 46.451413274
# Epoch: 0001 cost= 1079.846085548
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 46.943679810
# Epoch: 0001 cost= 1026.535514116
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 220.823993564
# STOPPED OVERFIT
# Epoch: 0001 cost= 994.707697630
# STOPPED OVERFIT
# Epoch: 0001 cost= 63.055738926
# STOPPED OVERFIT
# Epoch: 0001 cost= 1035.167491198
# STOPPED OVERFIT
# Epoch: 0001 cost= 63.631133080
# Epoch: 0001 cost= 1206.769511461
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 47.756573915
# STOPPED OVERFIT
# Epoch: 0001 cost= 1270.852617025
# Epoch: 0001 cost= 317.325540543
# STOPPED OVERFIT
# Epoch: 0001 cost= 1208.938692808
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 116.365703583
# Epoch: 0001 cost= 1296.071488380
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 31.559641600
# Epoch: 0001 cost= 1639.494236469
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 39.847584963
# STOPPED OVERFIT
# Epoch: 0001 cost= 872.288142920
# STOPPED OVERFIT
# Epoch: 0001 cost= 63.599055529
# Epoch: 0001 cost= 1039.237273216
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 99.240459323
# Epoch: 0001 cost= 1359.433734417
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 79.665535212
# Epoch: 0001 cost= 1266.382804871
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 129.764689684
# Epoch: 0001 cost= 1161.355910540
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 49.250495434
# Epoch: 0001 cost= 1107.880331516
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 49.624243736
# STOPPED OVERFIT
# Epoch: 0001 cost= 1089.806877613
# STOPPED OVERFIT
# Epoch: 0001 cost= 62.454118013
# Epoch: 0001 cost= 1197.665427446
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 73.789519072
# STOPPED OVERFIT
# Epoch: 0001 cost= 1007.884384394
# STOPPED OVERFIT
# Epoch: 0001 cost= 49.753679991
# Epoch: 0001 cost= 1246.574311972
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 42.075543284
# Epoch: 0001 cost= 1152.761043549
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 43.428969741
# Epoch: 0001 cost= 1208.015902996
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 49.016784191
# Epoch: 0001 cost= 1502.911253691
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 35.438009977
# Epoch: 0001 cost= 1001.139275074
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 42.784753084
# Epoch: 0001 cost= 1380.824020267
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 91.530110121
# STOPPED OVERFIT
# Epoch: 0001 cost= 1055.669839382
# STOPPED OVERFIT
# Epoch: 0001 cost= 62.666965723
# Epoch: 0001 cost= 1383.659832001
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 156.749215245
# STOPPED OVERFIT
# Epoch: 0001 cost= 1259.021275759
# STOPPED OVERFIT
# Epoch: 0001 cost= 63.116473913
# Epoch: 0001 cost= 1424.267381668
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 49.402843833
# Epoch: 0001 cost= 1259.489093781
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 61.417560935
# Epoch: 0001 cost= 1182.994940281
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 42.828809023
# Epoch: 0001 cost= 1092.677939177
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 43.320444703
# Epoch: 0001 cost= 1219.951599360
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 48.242191315
# Epoch: 0001 cost= 1234.106383324
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 60.082684278
# STOPPED OVERFIT
# Epoch: 0001 cost= 1047.331177711
# STOPPED OVERFIT
# Epoch: 0001 cost= 63.663491726
# Epoch: 0001 cost= 1253.549574375
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 43.057504535
# Epoch: 0001 cost= 1076.413390875
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 43.850162745
# Epoch: 0001 cost= 1168.340146780
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 60.603080273
# Epoch: 0001 cost= 1540.670714259
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 34.765465021
# Epoch: 0001 cost= 1301.355528355
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 44.497273445
# Epoch: 0001 cost= 1146.741525888
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 45.027170062
# Epoch: 0001 cost= 1168.730359316
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 43.354566216
# STOPPED OVERFIT
# Epoch: 0001 cost= 972.374721289
# STOPPED OVERFIT
# Epoch: 0001 cost= 63.152611732
# STOPPED OVERFIT
# Epoch: 0001 cost= 1384.898632288
# STOPPED OVERFIT
# Epoch: 0001 cost= 65.256815195
# Epoch: 0001 cost= 1097.511991978
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 236.014758945
# Epoch: 0001 cost= 1223.851030827
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 55.730563879
# Epoch: 0001 cost= 1535.917790174
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 36.942481518
# Epoch: 0001 cost= 1503.282511353
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 50.994508862
# STOPPED OVERFIT
# Epoch: 0001 cost= 1128.315048933
# Epoch: 0001 cost= 324.053493500
# STOPPED OVERFIT
# Epoch: 0001 cost= 1172.757662773
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 46.717613578
# Epoch: 0001 cost= 1462.113231897
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 54.640905142
# Epoch: 0001 cost= 1204.109049082
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 48.406556129
# Epoch: 0001 cost= 1254.914982319
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 49.824433565
# STOPPED OVERFIT
# Epoch: 0001 cost= 1096.158610821
# Epoch: 0001 cost= 319.283498049
# STOPPED OVERFIT
# Epoch: 0001 cost= 1035.173582792
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 44.795744419
# Epoch: 0001 cost= 1202.597410917
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 49.905654669
# Epoch: 0001 cost= 1039.994028807
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 65.085114717
# Epoch: 0001 cost= 1063.888405085
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 48.175234079
# Epoch: 0001 cost= 1628.400783300
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 117.054032445
# Epoch: 0001 cost= 1480.015998363
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 56.150217533
# Epoch: 0001 cost= 1127.037792206
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 116.951683640
# Epoch: 0001 cost= 1040.088029146
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 207.221714973
# Epoch: 0001 cost= 1163.320457697
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 43.311964035
# Epoch: 0001 cost= 1571.969436884
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 36.493967772
# STOPPED OVERFIT
# Epoch: 0001 cost= 948.777016163
# STOPPED OVERFIT
# Epoch: 0001 cost= 63.041406631
# Epoch: 0001 cost= 1542.337811112
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 33.993237972
# New generation is being created.
# new gen took:  363.9020562171936  s
# 32603.5820801
# [100, 360]
# [100, 360]
# [100, 360]
# [100, 360]
# [100, 360]
# [100, 360]
# [100, 360]
# [194, 100, 100, 360]
# [100, 360]
# [100, 360]
# [100, 360]
# [100, 360]
# [100, 360]
# [100, 360]
# [100, 360]
# [100, 360]
# [151, 100, 97, 172, 360]
# [191, 41, 100, 360]
# [191, 41, 100, 360]
# [114, 149, 145, 100, 149, 360]
# [191, 41, 100, 88, 149, 360]
# [151, 100, 360]
# [194, 100, 360]
# [41, 100, 360]
# [191, 100, 360]
# [151, 100, 360]
# [100, 360]
# [151, 100, 360]
# [100, 360]
# [191, 100, 360]
# [41, 100, 360]
# [100, 360]
# [100, 360]
# [100, 100, 360]
# [41, 100, 360]
# [100, 360]
# [100, 360]
# [100, 360]
# [100, 360]
# [100, 360]
# [100, 360]
# [151, 100, 360]
# [100, 360]
# [100, 360]
# [191, 41, 100, 360]
# [151, 100, 360]
# [100, 360]
# [100, 360]
# [100, 360]
# [100, 360]
# [191, 100, 360]
# [100, 360]
# [100, 360]
# [151, 41, 100, 360]
# [151, 100, 360]
# [100, 360]
# [191, 100, 360]
# [191, 100, 360]
# [100, 360]
# [114, 149, 100, 360]
# [191, 41, 100, 97, 172, 360]
# [191, 41, 100, 360]
# [100, 100, 360]
# [100, 360]
# [100, 360]
# [100, 360]
# [100, 360]
# [194, 100, 360]
# [100, 360]
# [100, 360]
# [100, 97, 172, 360]
# [191, 100, 100, 360]
# [100, 360]
# [100, 360]
# [100, 360]
# [41, 100, 360]
# [100, 360]
# [100, 360]
# [151, 145, 100, 149, 360]
# [191, 100, 97, 172, 360]
# Epoch: 0001 cost= 3497.409959316
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 40.610461831
# Epoch: 0001 cost= 1505.886084557
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 89.790788889
# Epoch: 0001 cost= 1401.569404364
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 38.038452387
# Epoch: 0001 cost= 1483.552525520
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 30.929823756
# Epoch: 0001 cost= 1358.253544331
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 34.330957770
# Epoch: 0001 cost= 1438.607169390
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 34.807567596
# Epoch: 0001 cost= 1533.567271709
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 48.470897198
# Epoch: 0001 cost= 1290.838350296
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 45.657054186
# Epoch: 0001 cost= 1304.017275810
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 33.997579575
# Epoch: 0001 cost= 1348.076278210
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 51.819996715
# Epoch: 0001 cost= 1619.413271427
# STOPPED OVERFIT
# Epoch: 0001 cost= 203.860670686
# STOPPED OVERFIT
# Epoch: 0001 cost= 1385.230862141
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 45.080107570
# Epoch: 0001 cost= 1543.968084574
# STOPPED OVERFIT
# Epoch: 0001 cost= 208.153562427
# STOPPED OVERFIT
# Epoch: 0001 cost= 1418.244592667
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 51.707151055
# Epoch: 0001 cost= 1570.675169230
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 35.847379327
# Epoch: 0001 cost= 1679.765727282
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 38.759286404
# Epoch: 0001 cost= 1076.180300951
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 48.631413460
# Epoch: 0001 cost= 1103.953127384
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 50.744350433
# Epoch: 0001 cost= 1267.461558342
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 49.369747162
# STOPPED OVERFIT
# Epoch: 0001 cost= 1022.521505594
# STOPPED OVERFIT
# Epoch: 0001 cost= 219.666996241
# Epoch: 0001 cost= 1123.153571367
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 186.548488617
# Epoch: 0001 cost= 1235.792762995
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 46.350782394
# Epoch: 0001 cost= 1368.637567759
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 46.097200751
# Epoch: 0001 cost= 1246.061655283
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 46.985134602
# Epoch: 0001 cost= 1299.642462969
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 51.476774216
# Epoch: 0001 cost= 1173.551596880
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 52.229240417
# Epoch: 0001 cost= 1259.444923520
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 58.291473508
# Epoch: 0001 cost= 1285.628371477
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 51.774079204
# Epoch: 0001 cost= 1448.227048278
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 42.215883851
# Epoch: 0001 cost= 1338.549109936
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 45.445394278
# Epoch: 0001 cost= 1290.815447330
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 57.240064383
# Epoch: 0001 cost= 1498.564973354
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 35.652284026
# Epoch: 0001 cost= 1588.503113747
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 36.437708855
# Epoch: 0001 cost= 1393.614378452
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 47.600764990
# Epoch: 0001 cost= 1308.483831644
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 55.497884750
# Epoch: 0001 cost= 1347.500152111
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 70.466909885
# Epoch: 0001 cost= 1500.143385172
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 48.568158984
# Epoch: 0001 cost= 1440.992993951
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 37.539029479
# Epoch: 0001 cost= 1282.002262235
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 37.070263147
# Epoch: 0001 cost= 1439.421605825
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 43.234693408
# Epoch: 0001 cost= 1386.556877017
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 103.721264839
# Epoch: 0001 cost= 1413.359354734
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 44.211414933
# Epoch: 0001 cost= 1394.378983021
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 52.089891553
# Epoch: 0001 cost= 1374.998947620
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 34.665919185
# Epoch: 0001 cost= 1205.852476835
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 45.700748444
# Epoch: 0001 cost= 1309.533739567
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 46.384801507
# Epoch: 0001 cost= 1429.356746435
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 46.469963431
# Epoch: 0001 cost= 1476.251265287
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 110.944589376
# Epoch: 0001 cost= 1482.417173862
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 32.923591971
# Epoch: 0001 cost= 1455.565926313
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 40.846340179
# Epoch: 0001 cost= 1149.549347639
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 46.386993647
# Epoch: 0001 cost= 1221.940119028
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 130.219013214
# Epoch: 0001 cost= 1322.124014854
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 74.818326831
# STOPPED OVERFIT
# Epoch: 0001 cost= 1417.045261383
# STOPPED OVERFIT
# Epoch: 0001 cost= 62.623817444
# Epoch: 0001 cost= 1366.896338940
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 44.581260681
# Epoch: 0001 cost= 1544.704440594
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 41.764098644
# Epoch: 0001 cost= 1256.476293564
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 44.492069244
# Epoch: 0001 cost= 1262.877761602
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 43.238419056
# Epoch: 0001 cost= 1328.431379318
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 58.037433028
# Epoch: 0001 cost= 1194.324091911
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 45.296287179
# Epoch: 0001 cost= 1162.560707092
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 49.916816235
# Epoch: 0001 cost= 1381.214241028
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 49.588634253
# Epoch: 0001 cost= 1271.958570004
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 46.098602176
# Epoch: 0001 cost= 1379.283092260
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 35.706326962
# Epoch: 0001 cost= 1417.127229929
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 186.390192151
# Epoch: 0001 cost= 1541.904180765
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 32.548314571
# Epoch: 0001 cost= 1351.161453128
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 38.324613214
# Epoch: 0001 cost= 1322.687162399
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 46.733824015
# Epoch: 0001 cost= 1531.888994336
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 33.219936609
# Epoch: 0001 cost= 1412.980960369
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 44.522106528
# Epoch: 0001 cost= 1210.171218157
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 70.950963140
# Epoch: 0001 cost= 1203.405790091
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 43.485926628
# Epoch: 0001 cost= 1381.716276050
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 35.834168911
# Epoch: 0001 cost= 1357.220118046
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 153.174142480
# Epoch: 0001 cost= 1577.744497061
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 35.466359496
# Epoch: 0001 cost= 1253.755857944
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 47.335654259
# Epoch: 0001 cost= 1695.355897903
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 33.888684988
# Epoch: 0001 cost= 1317.366875410
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 36.072625399
# Epoch: 0001 cost= 1098.313470364
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 49.702873468
# Epoch: 0001 cost= 1117.866722584
# STOPPED OVERFIT
# STOPPED OVERFIT
# Epoch: 0001 cost= 45.200289249
# New generation is being created.
