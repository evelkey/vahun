# %%
from vahun.tools import logread
import matplotlib
# %matplotlib inline
matplotlib.style.use('ggplot')
matplotlib.pyplot.rcParams['figure.figsize'] = (15, 3)
matplotlib.pyplot.rcParams['font.family'] = 'sans-serif'

# %%
log=logread()
log.plot_accuracy(filter="mark")
# Out:
# ['autoencoder_unique_160_20170412012856', ['Language', 'Hun'], ['Wordcount', '1454976'], ['Unique words', '214708'], ['Population size', '40'], ['Encoding dim', '160'], ['Encoder type', 'autoencoder_unique_with_mark160'], ['nonlinear', '<function sigmoid at 0x7fecf61c9730>'], ['population_size', '40']]
# Max test accuracy: 0.9754739641417174
# Max train accuracy: 0.9756214210650481
# With config:  [160, 380]
# ['autoencoder_unique_120_20170412103349', ['Language', 'Hun'], ['Wordcount', '1454976'], ['Unique words', '214708'], ['Population size', '10'], ['Encoding dim', '120'], ['Encoder type', 'autoencoder_unique_with_mark120'], ['nonlinear', '<function sigmoid at 0x7f54eba89730>'], ['population_size', '10']]
# Max test accuracy: 0.9481341683108861
# Max train accuracy: 0.9500868595448989
# With config:  [120, 270, 380]
# ...
