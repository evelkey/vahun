# %%
from vahun.tools import logread
import matplotlib
# %matplotlib inline
matplotlib.style.use('ggplot')
matplotlib.pyplot.rcParams['figure.figsize'] = (15, 3)
matplotlib.pyplot.rcParams['font.family'] = 'sans-serif'

# %%
log=logread()
log.plot_accuracy(filter="uniq")
# Out:
# ['variational_unique_180_20170325215709', ['Language', 'Hun'], ['Wordcount', '182300'], ['Unique words', '182300'], ['Population size', '1'], ['Encoding dim', '180'], ['Encoder type', 'variational_unique_180']]
# Max test accuracy: 0.9602443332352075
# Max train accuracy: 0.9606395505728234
# With config:  [180, 360]
# ['variational_unique_10_20170325014150', ['Language', 'Hun'], ['Wordcount', '116596'], ['Unique words', '116596'], ['Population size', '1'], ['Encoding dim', '10'], ['Encoder type', 'variational_unique_10']]
# Max test accuracy: 0.9625164401578256
# Max train accuracy: 0.9633713283647523
# With config:  [180, 360]
# ['auto_unique_60_20170325014922', ['Language', 'Hun'], ['Wordcount', '182300'], ['Unique words', '182300'], ['Population size', '1'], ['Encoding dim', '60'], ['Encoder type', 'Demo_60']]
# Max test accuracy: 0.9657737219114906
# Max train accuracy: 0.9660967053455339
# With config:  [180, 360]
# ...
